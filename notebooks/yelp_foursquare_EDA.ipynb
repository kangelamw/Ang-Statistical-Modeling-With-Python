# %%
# imports
import pandas as pd
import json
import requests # This library will be used to call the APIs
import os # Use this library to access environment variable(s)
from dotenv import load_dotenv # Use this library to load the environment variables into the code
import time # Use this library to pause the program for a specified amount of time

# %%
# Load the keys
load_dotenv()
FOURSQUARE_API_KEY = os.getenv('FOURSQUARE_API_KEY')
YELP_API_KEY = os.getenv('YELP_API_KEY')

# %%
# Load Citybikes Data
citybikes = pd.read_csv('../data/citybikes.csv')

citybikes.columns
# Out:
# Index(['station_id', 'station_name', 'station_address', 'station_latitude',
#        'station_longitude', 'available_bikes', 'empty_bike_slots'],
#       dtype='object')

# %% [markdown]
# ### Testing API connections.

# %%
# Test parameters, Lat/Lon for Hamilton
test_lat = 43.2557
test_lon = -79.8711

# %%
# Foursquare
def test_foursquare_api():
  url = "https://api.foursquare.com/v3/places/search"
  headers = {
    "Authorization": FOURSQUARE_API_KEY,
    "Accept": "application/json"
  }
  params = {
    "ll": f"{test_lat},{test_lon}",
    "query": "restaurant",
    "radius": 1000,
    "limit": 1  # Keep this minimal for testing
  }
  try:
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    print("Foursquare API Test: SUCCESS")
    print(f"Response Code: {response.status_code}")
  except requests.exceptions.HTTPError as http_err:
    print("Foursquare API Test: FAILED")
    print(f"HTTP Error: {http_err}")
  except Exception as err:
    print("Foursquare API Test: FAILED")
    print(f"Other Error: {err}")
    

# Run tests
print("\nTesting Foursquare API...")
test_foursquare_api()
# Out:
# Testing Foursquare API...
# Foursquare API Test: SUCCESS
# Response Code: 200

# %%
# Yelp
def test_yelp_api():
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {
        "Authorization": f"Bearer {YELP_API_KEY}",
        "Accept": "application/json"
    }
    params = {
        "latitude": test_lat,
        "longitude": test_lon,
        "categories": "restaurants",
        "radius": 1000,
        "limit": 1
    }
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        print("Yelp API Test: SUCCESS")
        print(f"Response Code: {response.status_code}")
    except requests.exceptions.HTTPError as http_err:
        print("Yelp API Test: FAILED")
        print(f"HTTP Error: {http_err}")
    except Exception as err:
        print("Yelp API Test: FAILED")
        print(f"Other Error: {err}")

# Run tests
print("Testing Yelp API...")
test_yelp_api()
# Out:
# Testing Yelp API...
# Yelp API Test: SUCCESS
# Response Code: 200

# %% [markdown]
# As instructed, we will search for some Points of Interest (POIs). The following have been selected:
#
# - `restaurants` on Yelp -- "13065" on Foursquare
# - `museums` on Yelp -- "10027" on Foursquare
# -  `amusementparks` on Yelp -- "10001" on Foursquare

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Foursquare
def query_foursquare(lat, lon, categories, radius=1000, limit=50):
      url = "https://api.foursquare.com/v3/places/search"
      headers = {
            'Authorization' : FOURSQUARE_API_KEY,
            'Accept' : 'application/json'
      }
      params = {
      'll': f"{lat},{lon}",
      'categories': categories,
      'radius': radius,
      'limit': limit
      }
  
      try:
            response = requests.get(url, headers=headers, params=params)
            
            # Handle rate limiting
            if response.status_code == 429:
                  retry_after = int(response.headers.get('Retry-After', 20))
                  print(f"Rate limit exceeded. Retrying after {retry_after} seconds.")
                  time.sleep(retry_after)
                  response = requests.get(url, headers=headers, params=params)
                  
            # Raise exception for HTTP errors
            response.raise_for_status()
            data = response.json()
            return data.get('results', [])
      except requests.exceptions.HTTPError as http_err:
            print(f"HTTP error occurred: {http_err} - Status Code: {response.status_code}")
      except Exception as err:
            print(f"An error occurred: {err}")
    
      return []

# %%
# FSQ Categories
categories_fsq = ['13065', # restaurants
                 '10027', # museums
                 '10001'] # amusement parks

# %%
# Test Query
query_foursquare(test_lat, test_lon, categories_fsq[0], radius=1000, limit=1)
# Out:
# [{'fsq_id': '55de230f498eecf46f6652a2',
#   'categories': [{'id': 13306,
#     'name': 'Taco Restaurant',
#     'short_name': 'Tacos',
#     'plural_name': 'Taco Restaurants',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'closed_bucket': 'VeryLikelyOpen',
#   'distance': 359,
#   'geocodes': {'drop_off': {'latitude': 43.257143, 'longitude': -79.86724},
#    'main': {'latitude': 43.257258, 'longitude': -79.867202},
#    'roof': {'latitude': 43.257258, 'longitude': -79.867202}},
#   'link': '/v3/places/55de230f498eecf46f6652a2',
#   'location': {'address': '41 King William St',
#    'country': 'CA',
#    'cross_street': 'Hughson',
#    'formatted_address': '41 King William St (Hughson), Hamilton ON L8R 1A2',
#    'locality': 'Hamilton',
#    'postcode': 'L8R 1A2',
#    'region': 'ON'},
#   'name': 'The Mule',
#   'related_places': {},
#   'timezone': 'America/Toronto'}]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# Store results
fsq_poi_results = []

total_stations = len(citybikes)

# %%
# Iterate over each bike station
for index, station in citybikes.iterrows():
    lat = station['station_latitude']
    lon = station['station_longitude']
    station_id = station['station_id']
    station_name = station['station_name'] # Streaming output to console
    print(f"Processing Station {index + 1}/{total_stations}: {station_name}")

    # Iterate over each search term category
    for category in categories_fsq:
        fsq_pois = query_foursquare(lat, lon, category)
        
        # Parse each POI and append to results
        for poi in fsq_pois:
            fsq_poi_data = {
                'fsq_id': poi.get('fsq_id'), 
                'poi_name': poi.get('name'),
                'poi_category_id': category,
                'poi_rating': poi.get('rating'),
                'poi_review_count': poi.get('stats', {}).get('total_ratings'),
                'poi_latitude': poi.get('geocodes', {}).get('main', {}).get('latitude'),
                'poi_longitude': poi.get('geocodes', {}).get('main', {}).get('longitude'),
                'poi_address': poi.get('location', {}).get('formatted_address', []),
                'postal_code': poi.get('location', {}).get('postal_code'),
                'station_id': station_id,
                'distance_from_station': poi.get('distance')
            }
            fsq_poi_results.append(fsq_poi_data)
        print("Entered. Waiting...")
        time.sleep(0.25) # Sleep for 250ms to avoid rate limiting
# Out:
# Processing Station 1/190: Bay at Strachan
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 2/190: MAC Rack ITB
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 3/190: Augusta at John
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 4/190: Hunter GO Centre
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 5/190: Maple at Rothsay - ERI08
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 6/190: Whitney at Lower Horning
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 7/190: Frid at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 8/190: Locke at Hunter
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 9/190: Mac Rack Kingswalk Bridge
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 10/190: James North at Mulberry
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 11/190: MAC Rack IAHS West
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 12/190: MAC Rack Temporary Lecture Theater
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 13/190: Sterling at Whitton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 14/190: Locke at Herkimer
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 15/190: Ferguson at King William
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 16/190: King at Graham
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 17/190: George Street
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 18/190: King at Mary
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 19/190: King at Barnesdale
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 20/190: Ferrie at Ferguson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 21/190: Aberdeen at Queen
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 22/190: King George
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 23/190: Cumberland at Blake
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 24/190: King at Dunsmure - ERI09
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 25/190: Barton at Wentworth
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 26/190: MAC Rack Childrens Centre
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 27/190: Eastwood Arena
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 28/190: Dundurn Stairs
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 29/190: West Harbour GO Station
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 30/190: City Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 31/190: Main at Macnab
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 32/190: York at Macnab
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 33/190: Maplewood at Springer
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 34/190: Stinson at Blythe
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 35/190: MAC Rack CRL North
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 36/190: Forsyth at Sterling
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 37/190: Main at Columbia College
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 38/190: Ainslie at Emerson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 39/190: Charlton at Locke
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 40/190: Sherman at Barton - ERI02
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 41/190: MAC Rack ITB South
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 42/190: King William at Hughson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 43/190: Oxford at York
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 44/190: Main at Dundurn
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 45/190: Haymarket at Hughson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 46/190: James S at Charlton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 47/190: Pier 4
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 48/190: Sterling at Haddon
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 49/190: Jackson Square
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 50/190: Durand Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 51/190: Dunsmure at Sherman - ERI10
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 52/190: King Street Dundas
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 53/190: MAC Rack MDCL North
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 54/190: Wentworth at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 55/190: Beasley Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 56/190: A.M Cunningham Elementary School
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 57/190: Osler at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 58/190: Hess at king
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 59/190: Westdale Aviary
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 60/190: 270 Sherman
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 61/190: Main at Dalewood
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 62/190: MAC Rack JHE ABB @ College Crescent
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 63/190: Strachan at Mary
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 64/190: Ottawa at Dunsmure - ERI07
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 65/190: MAC Rack Go Terminal
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 66/190: Westinghouse at Barton - ERI13
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 67/190: Mac Track
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 68/190: McMaster Emerson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 69/190: MAC Rack Lot B
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 70/190: MAC Rack Divinity College East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 71/190: Mars at Wentworth - ERI01
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 72/190: Chedoke Stairs
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 73/190: Discovery Drive
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 74/190: Sanders at Binkley
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 75/190: RBG Rock Garden
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 76/190: MAC Rack West Quad
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 77/190: MAC Rack Brandon & Woodstock Halls
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 78/190: Wentworth Stairs
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 79/190: Pier 8
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 80/190: York at Inchbury
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 81/190: Corktown Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 82/190: Cannon at Wentworth - 96
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 83/190: King at Sherman
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 84/190: Mac Rack - Performance Ctr.
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 85/190: H.A.A.A. Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 86/190: James at Vine
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 87/190: Hunter at Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 88/190: Catharine at Forest
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 89/190: Cootes Drive Dundas
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 90/190: Charlton at Queen
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 91/190: Main and Wellington
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 92/190: Belview at Cannon - ERI12
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 93/190: McMaster Parking Lot M
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 94/190: Westdale Library
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 95/190: King William at Victoria
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 96/190: MAC Rack BSB
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 97/190: Barton at Ottawa - ERI06
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 98/190: Bay at Macaulay
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 99/190: Emerson at Whitney
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 100/190: MAC Rack ABB East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 101/190: MAC Rack MDCL Kingswalk
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 102/190: Cannon at Birch (Powell Park)
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 103/190: Macklin at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 104/190: AM Cunningham Parkette
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 105/190: Cannon at Steven
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 106/190: King at Sanford
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 107/190: Queen at George
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 108/190: MAC Rack Hedden Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 109/190: MAC Rack BSB North
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 110/190: Princess Point
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 111/190: James at Colbourne
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 112/190: Tisdale at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 113/190: Ferguson at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 114/190: MAC Rack TSH
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 115/190: Main at Longwood
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 116/190: Queen at Peter
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 117/190: Stadium
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 118/190: Rail Trail at Emerson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 119/190: Locke at Napier
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 120/190: Victoria at Barton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 121/190: MAC Rack IWC Patient Area
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 122/190: West at Cannon
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 123/190: Osler at Grant
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 124/190: Mac Rack Preliminary Lab
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 125/190: Dundurn at Aberdeen
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 126/190: MAC Rack Commons
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 127/190: Hill Street Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 128/190: MAC Rack JHE
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 129/190: McMaster Mary Keyes
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 130/190: Bay at Bold
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 131/190: James at Guise
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 132/190: Gore Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 133/190: Sanders at Hollywood
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 134/190: MAC Rack General Science Building
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 135/190: John at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 136/190: Stinson at West
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 137/190: MAC Rack DeGroote School of Business
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 138/190: Rail Trail at Stroud
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 139/190: MAC Rack Scholars Rd. at University Ave.
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 140/190: RT Steele Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 141/190: MAC Rack HATCH
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 142/190: MAC Rack The Hub
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 143/190: Bay at Mulberry
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 144/190: Barton at Lottridge - ERI03
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 145/190: Cannon at Ottawa
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 146/190: Duke at James
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 147/190: Ferguson at Cannon
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 148/190: McMaster Innovation Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 149/190: John near King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 150/190: Delaware at Myrtle
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 151/190: King William at James
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 152/190: McMaster Student Centre
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 153/190: MAC Rack Edwards Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 154/190: Athletic Centre Bike Racks
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 155/190: Hughson at Picton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 156/190: Cootes at York and King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 157/190: Bayfront Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 158/190: Main at Whitney
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 159/190: Dundurn St S
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 160/190: McMaster Health Sciences
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 161/190: MAC Rack Bates Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 162/190: McMaster Arthur Bourns
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 163/190: Westdale Village
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 164/190: Barton and Belview - ERI05
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 165/190: Cannon at Sherman
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 166/190: Longwood at Edgevale
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 167/190: King at Cline
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 168/190: Main at Eastbourne
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 169/190: The Chelsea Hub (Augusta near Hughson)
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 170/190: King at Dundurn
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 171/190: Gage Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 172/190: Park at Robinson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 173/190: Bay at York
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 174/190: Ferguson at Barton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 175/190: Rifle Range at Rail Trail
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 176/190: Pearl Street Bridge
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 177/190: MAC Rack Thode Library
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 178/190: Longwood at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 179/190: Cannon at East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 180/190: MAC Rack CRL South
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 181/190: Hunter at Ferguson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 182/190: MAC Rack PGCLL
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 183/190: Aberdeen at Studholme
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 184/190: Hunter at Hess
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 185/190: MAC Rack LR Wilson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 186/190: Main and London - Pipeline Trail Entrance
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 187/190: MAC Rack Soccer Field
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 188/190: MAC Rack Mary Keyes East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 189/190: McMaster McKay
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 190/190: Seedworks
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
foursquare = pd.DataFrame(fsq_poi_results)

# %%
# Add station name
foursquare['station_name'] = foursquare['station_id'].map(citybikes.set_index('station_id')['station_name'])

print(foursquare.shape)
print(foursquare.columns)
# Out:
# (8698, 12)
# Index(['fsq_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
foursquare.head(1)
# Out:
#                      fsq_id poi_name poi_category_id poi_rating  \
# 0  5ba0f82a15173e002c280c07  Synonym           13065       None
#
#   poi_review_count  poi_latitude  poi_longitude  \
# 0             None     43.264558     -79.865376
#
#                                          poi_address postal_code  \
# 0  328 James St N (Barton Street West), Hamilton ...        None
#
#                          station_id  distance_from_station     station_name
# 0  024a3edf037cb411d16acc08a7fcb954                    420  Bay at Strachan

# %%
# Convert to CSV
foursquare.to_csv('../data/raw/foursquare.csv', index=False)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Yelp
def query_yelp(lat, lon, categories, radius=1000, limit=50):
  url = "https://api.yelp.com/v3/businesses/search"
  headers = {
    "Authorization": f"Bearer {YELP_API_KEY}",
    "Accept": "application/json"
  }
  params = {
    "latitude": lat,
    "longitude": lon,
    "categories": categories,
    "radius": radius,
    "limit": limit
  }
    
  try:
    response = requests.get(url, headers=headers, params=params)
        
    # Handle rate limiting
    if response.status_code == 429:
      retry_after = int(response.headers.get('Retry-After', 20))
      print(f"Rate limit exceeded. Retrying after {retry_after} seconds.")
      time.sleep(retry_after)
      response = requests.get(url, headers=headers, params=params)
    
    # Raise exception for HTTP errors
    response.raise_for_status()
    data = response.json()
    return data.get('businesses', [])
    
  except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err} - Status Code: {response.status_code}")
  except Exception as err:
    print(f"An error occurred: {err}")
    
  return []

# %%
# Yelp Categories
categories_yelp = ['restaurants', 'museums', 'amusementparks']

# %%
# Test Yelp
query_yelp(test_lat, test_lon, categories_yelp[0], radius=1000, limit=1)
# Out:
# [{'id': '752Fv2jKafftvoS3Twkqyg',
#   'alias': 'hambrgr-hamilton',
#   'name': 'Hambrgr',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/18TdNrY_d9j0iVlvIcVb3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=GeuIqjL6ofUJ72HeWCsLHw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GeuIqjL6ofUJ72HeWCsLHw',
#   'review_count': 216,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '49 King William Street',
#    'address2': None,
#    'address3': '',
#    'city': 'Hamilton',
#    'zip_code': 'L8R 1A2',
#    'country': 'CA',
#    'state': 'ON',
#    'display_address': ['49 King William Street',
#     'Hamilton, ON L8R 1A2',
#     'Canada']},
#   'phone': '+12893891212',
#   'display_phone': '+1 289-389-1212',
#   'distance': 377.3430524726985,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_accepts_apple_pay': False,
#    'business_url': 'http://www.hambrgr.ca',
#    'about_this_biz_bio_photo_dict': None,
#    'about_this_biz_business_recommendation': [],
#    'business_temp_closed': None,
#    'about_this_biz_bio': None,
#    'about_this_biz_bio_first_name': None,
#    'about_this_biz_bio_last_name': None,
#    'about_this_biz_history': None,
#    'about_this_biz_role': None,
#    'about_this_biz_specialties': None,
#    'about_this_biz_year_established': None,
#    'accepted_cards': {'credit': True, 'none': False, 'debit': True},
#    'alcohol': 'full_bar',
#    'ambience': {'hipster': True,
#     'casual': True,
#     'touristy': False,
#     'trendy': None,
#     'intimate': False,
#     'romantic': False,
#     'classy': False,
#     'upscale': False},
#    'best_nights': {'monday': False,
#     'tuesday': False,
#     'wednesday': False,
#     'thursday': False,
#     'friday': False,
#     'saturday': False,
#     'sunday': False},
#    'bike_parking': True,
#    'business_parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'caters': False,
#    'dogs_allowed': None,
#    'drive_thru': False,
#    'good_for_dancing': False,
#    'good_for_kids': True,
#    'good_for_meal': {'breakfast': False,
#     'brunch': False,
#     'lunch': True,
#     'dinner': True,
#     'latenight': None,
#     'dessert': False},
#    'happy_hour': True,
#    'has_pool_table': None,
#    'has_tv': True,
#    'menu_url': 'http://hambrgr.ca/menu-king-william',
#    'noise_level': 'average',
#    'open24_hours': None,
#    'platform_delivery': None,
#    'restaurants_delivery': True,
#    'restaurants_good_for_groups': True,
#    'restaurants_reservations': True,
#    'restaurants_table_service': True,
#    'restaurants_take_out': True,
#    'waitlist_reservation': None,
#    'wi_fi': 'free',
#    'liked_by_vegans': True,
#    'liked_by_vegetarians': False,
#    'outdoor_seating': True,
#    'hot_and_new': None}}]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# Store results
yelp_poi_results = []

total_stations = len(citybikes)
batch = (len(citybikes) / 2)

print(f"total_stations: {total_stations}")
print(f"batch: {batch}")

batch1 = citybikes.iloc[:int(batch)] # First half
batch2 = citybikes.iloc[int(batch):] # Second half
# Out:
# total_stations: 190
# batch: 95.0

# %%
# Iterate over each bike station
for index, station in batch2.iterrows(): # We are processing by batch.
    lat = station['station_latitude']
    lon = station['station_longitude']
    station_id = station['station_id']
    station_name = station['station_name'] # Streaming output to console
    
    # We are processing by batch.
    print(f"Processing Station {index + 1}/{len(batch2)}: {station_name}")
  
  # Iterate over each search term category group
    for category in categories_yelp:
      yelp_pois = query_yelp(lat, lon, category, radius=1000, limit=50)
    
      # Parse each POI and append to results
      for poi in yelp_pois:
        yelp_poi_data = {
          'yelp_id': poi.get('id'),
          'poi_name': poi.get('name'),
          'poi_category_id': category,
          'poi_rating': poi.get('rating'),
          'poi_review_count': poi.get('review_count'),
          'poi_latitude': poi.get('coordinates', {}).get('latitude'),
          'poi_longitude': poi.get('coordinates', {}).get('longitude'),
          'poi_address': poi.get('location', {}).get('display_address', []),
          'postal_code': poi.get('location', {}).get('zip_code'),
          'station_id': station_id,
          'distance_from_station': poi.get('distance'),
          'station_name': station_name
        }
        
        yelp_poi_results.append(yelp_poi_data)
      print("Entered. Waiting...")
      time.sleep(0.25) # Sleep for 250ms to avoid rate limiting
# Out:
# Processing Station 96/95: MAC Rack BSB
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 97/95: Barton at Ottawa - ERI06
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 98/95: Bay at Macaulay
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 99/95: Emerson at Whitney
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 100/95: MAC Rack ABB East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 101/95: MAC Rack MDCL Kingswalk
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 102/95: Cannon at Birch (Powell Park)
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 103/95: Macklin at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 104/95: AM Cunningham Parkette
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 105/95: Cannon at Steven
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 106/95: King at Sanford
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 107/95: Queen at George
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 108/95: MAC Rack Hedden Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 109/95: MAC Rack BSB North
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 110/95: Princess Point
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 111/95: James at Colbourne
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 112/95: Tisdale at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 113/95: Ferguson at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 114/95: MAC Rack TSH
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 115/95: Main at Longwood
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 116/95: Queen at Peter
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 117/95: Stadium
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 118/95: Rail Trail at Emerson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 119/95: Locke at Napier
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 120/95: Victoria at Barton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 121/95: MAC Rack IWC Patient Area
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 122/95: West at Cannon
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 123/95: Osler at Grant
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 124/95: Mac Rack Preliminary Lab
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 125/95: Dundurn at Aberdeen
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 126/95: MAC Rack Commons
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 127/95: Hill Street Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 128/95: MAC Rack JHE
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 129/95: McMaster Mary Keyes
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 130/95: Bay at Bold
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 131/95: James at Guise
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 132/95: Gore Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 133/95: Sanders at Hollywood
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 134/95: MAC Rack General Science Building
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 135/95: John at Main
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 136/95: Stinson at West
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 137/95: MAC Rack DeGroote School of Business
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 138/95: Rail Trail at Stroud
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 139/95: MAC Rack Scholars Rd. at University Ave.
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 140/95: RT Steele Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 141/95: MAC Rack HATCH
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 142/95: MAC Rack The Hub
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 143/95: Bay at Mulberry
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 144/95: Barton at Lottridge - ERI03
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 145/95: Cannon at Ottawa
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 146/95: Duke at James
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 147/95: Ferguson at Cannon
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 148/95: McMaster Innovation Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 149/95: John near King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 150/95: Delaware at Myrtle
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 151/95: King William at James
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 152/95: McMaster Student Centre
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 153/95: MAC Rack Edwards Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 154/95: Athletic Centre Bike Racks
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 155/95: Hughson at Picton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 156/95: Cootes at York and King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 157/95: Bayfront Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 158/95: Main at Whitney
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 159/95: Dundurn St S
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 160/95: McMaster Health Sciences
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 161/95: MAC Rack Bates Hall
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 162/95: McMaster Arthur Bourns
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 163/95: Westdale Village
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 164/95: Barton and Belview - ERI05
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 165/95: Cannon at Sherman
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 166/95: Longwood at Edgevale
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 167/95: King at Cline
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 168/95: Main at Eastbourne
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 169/95: The Chelsea Hub (Augusta near Hughson)
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 170/95: King at Dundurn
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 171/95: Gage Park
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 172/95: Park at Robinson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 173/95: Bay at York
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 174/95: Ferguson at Barton
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 175/95: Rifle Range at Rail Trail
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 176/95: Pearl Street Bridge
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 177/95: MAC Rack Thode Library
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 178/95: Longwood at King
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 179/95: Cannon at East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 180/95: MAC Rack CRL South
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 181/95: Hunter at Ferguson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 182/95: MAC Rack PGCLL
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 183/95: Aberdeen at Studholme
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 184/95: Hunter at Hess
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 185/95: MAC Rack LR Wilson
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 186/95: Main and London - Pipeline Trail Entrance
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 187/95: MAC Rack Soccer Field
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 188/95: MAC Rack Mary Keyes East
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 189/95: McMaster McKay
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...
# Processing Station 190/95: Seedworks
# Entered. Waiting...
# Entered. Waiting...
# Entered. Waiting...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Batch 1
yelp1 = pd.DataFrame(yelp_poi_results)

print(yelp1.shape)
print(yelp1.columns)
# Out:
# (4992, 12)
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
# Backup Batch 1
yelp1.to_csv('../data/raw/yelp1.csv', index=False)

# %%
# Batch 2
yelp2 = pd.DataFrame(yelp_poi_results)

print(yelp2.shape)
print(yelp2.columns)
# Out:
# (5030, 12)
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
# Backup Batch 2
yelp2.to_csv('../data/raw/yelp2.csv', index=False)

# %%
# Load Backups
yelp1 = pd.read_csv('../data/raw/yelp1.csv')
yelp2 = pd.read_csv('../data/raw/yelp2.csv')

# %%
# Merge
yelp = pd.concat([yelp1, yelp2])

print(yelp.shape)
print(yelp.columns)
# Out:
# (10022, 12)
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
yelp.head(1)
# Out:
#                   yelp_id             poi_name poi_category_id  poi_rating  \
# 0  fNfZ0bOEvXOxMP1vDEDi8w  Pirate Life Theatre  amusementparks         0.0
#
#    poi_review_count  poi_latitude  poi_longitude  \
# 0                 0     43.268525     -79.870901
#
#                                          poi_address postal_code  \
# 0  ['200 Harbour Front Drive', 'Hamilton, ON L8L ...     L8L 1C8
#
#                          station_id  distance_from_station     station_name
# 0  024a3edf037cb411d16acc08a7fcb954             242.169774  Bay at Strachan

# %%
# Convert to CSV
yelp.to_csv('../data/raw/yelp.csv', index=False)

# %% [markdown]
# # Comparing Results

# %%
# Load CSVs
foursquare = pd.read_csv('../data/raw/foursquare.csv')
yelp = pd.read_csv('../data/raw/yelp.csv')

# %%
# FSQ
print(foursquare.shape)
print(foursquare.nunique())
# Out:
# (8698, 12)
# fsq_id                   669
# poi_name                 586
# poi_category_id            3
# poi_rating                 0
# poi_review_count           0
# poi_latitude             601
# poi_longitude            608
# poi_address              593
# postal_code                0
# station_id               190
# distance_from_station    986
# station_name             190
# dtype: int64

# %%
# Yelp
print(yelp.shape)
print(yelp.nunique())
# Out:
# (10022, 12)
# yelp_id                   529
# poi_name                  485
# poi_category_id             3
# poi_rating                 41
# poi_review_count           74
# poi_latitude              493
# poi_longitude             500
# poi_address               494
# postal_code               330
# station_id                190
# distance_from_station    9523
# station_name              190
# dtype: int64

# %%
# Column names, extracting from foursquare -- Doesn't matter, Yelp has the same columns.
a = foursquare.columns
b = a[1:(len(a)-1)]

column_names = [i for i in b]
print(column_names)
# Out:
# ['poi_name', 'poi_category_id', 'poi_rating', 'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address', 'postal_code', 'station_id', 'distance_from_station']

# %%
# FSQ values
c = foursquare.nunique()
d = c[1:(len(c)-1)]

fsq = [i for i in d]
print(f"Foursquare: {fsq}")

# Yelp values
e = yelp.nunique()
f = e[1:(len(e)-1)]

yelp = [i for i in f]
print(f"Yelp: {yelp}")
# Out:
# Foursquare: [586, 3, 0, 0, 601, 608, 593, 0, 190, 986]
# Yelp: [485, 3, 41, 74, 493, 500, 494, 330, 190, 9523]

# %%
# Merge
compare = pd.DataFrame(
  {
    'column_names': column_names,
    'foursquare': fsq,
    'yelp': yelp
  }
).reset_index(drop=True)

compare = compare.drop([len(compare)-2]) # Drop station_id row

# %%
compare
# Out:
#             column_names  foursquare  yelp
# 0               poi_name         586   485
# 1        poi_category_id           3     3
# 2             poi_rating           0    41
# 3       poi_review_count           0    74
# 4           poi_latitude         601   493
# 5          poi_longitude         608   500
# 6            poi_address         593   494
# 7            postal_code           0   330
# 9  distance_from_station         986  9523

# %%
# For showing only
# print(compare.to_markdown(index=False))

# %% [markdown]
# ## Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# #### Unique Values -- <i>`(df.nunique())`</i>
# | column_names          |   foursquare |   yelp |
# |:----------------------|-------------:|-------:|
# | poi_name              |          586 |    485 |
# | poi_category_id       |            3 |      3 |
# | poi_rating            |            0 |     41 |
# | poi_review_count      |            0 |     74 |
# | poi_latitude          |          601 |    493 |
# | poi_longitude         |          608 |    500 |
# | poi_address           |          593 |    494 |
# | postal_code           |            0 |    330 |
# | distance_from_station |          986 |   9523 |

# %% [markdown]
# ### Initial Observations:
# - Foursquare contains more unique POIs (Point of Interest names) than Yelp.
# - Yelp provides ratings, while Foursquare does not.
# - Yelp provides review counts, while Foursquare does not.
# - Foursquare has more unique addresses, suggesting a larger variety of exact POI locations.
# - Yelp includes postal codes separately, while Foursquare includes it in the formatted address. I specifically called the complete address from Foursquare. [Here's where we fixed it.](../data/cleaning.ipynb)
#
# ### Key Differences:
# 1. Data Richness
#   - Yelp provides more detailed metadata for each POI, including poi_rating and poi_review_count, which are absent or incomplete in Foursquare.
#   - Foursquare, however, captures more unique POIs and geographical diversity (poi_latitude, poi_longitude, and poi_address).
# 2. Distance Data
#   - Yelp has significantly more unique distance_from_station values compared to Foursquare (9,523 vs. 986). This could indicate that Yelp uses more precise or dynamic calculations for distances
# 3. POI Identification
#   - Foursquare has more unique poi_name entries (586 vs. 485), suggesting broader POI coverage or naming diversity.
#
# ### Considerations for Use:
#
# **I. Coverage**
#
# If the goal is to analyze broader POI coverage with less focus on reviews, Foursquare might be more suitable.
#
# For richer metadata and finer granularity, Yelp is better.
#
# **II. Data Completeness**
#
# Yelp offers ratings and review counts, which can be useful for analyzing popularity or quality.
#
# Foursquare’s broader geographic and POI coverage could be valuable for location-specific analyses.
#
# **III. Integration**
#
# Matching datasets may require careful handling of poi_name and poi_address, as Foursquare has more unique values, potentially with more variations.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %% [markdown]
# > The data requires some cleaning. Check out the process [here](../data/cleaning.ipynb).

# %%
# FSQ did not come with ratings, so we'll get rating data from Yelp.

# Load cleaned Yelp Data
yelp_cleaned = pd.read_csv('../data/pois_only/pois_yelp.csv')

yelp_cleaned.head()
# Out:
#                   yelp_id                               poi_name  \
# 0  OglGsGS-GdMeSxAvjdzfLQ  2 For 1 Pizza Wings & Subs Restaurant
# 1  XABRVIvmufpfZ2J1llV9MA                              28 Lister
# 2  Zr-TN76nzcRVEgJwZHX_7g         5 Alarm Wings And Fish & Chips
# 3  CODMFMsPP06eTQutMnniUA                  541 Eatery & Exchange
# 4  12GctL58qX4G9bS2kBomHg                       A & J Sugar Bowl
#
#   poi_category_id  poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 0     restaurants         1.5                 4     43.245080     -79.807620
# 1     restaurants         1.0                 1     43.257621     -79.868547
# 2     restaurants         2.9                 8     43.234640     -79.856750
# 3     restaurants         4.5                45     43.258248     -79.842354
# 4     restaurants         4.3                 8     43.260971     -79.868778
#
#                   poi_address postal_code
# 0     158 Kenilworth Avenue N     L8H 4R8
# 1        28 James Street  L8R         NaN
# 2  553 Upper Wentworth Street     L9A 4T8
# 3         541 Barton Street E     L8L 2Z2
# 4         124 MacNab Street N     L9H 2K1

# %%
sorted = yelp_cleaned.sort_values(by=['poi_rating', 'poi_review_count'], ascending=False)

restaurants = sorted[sorted['poi_category_id'] == 'restaurants']
top_10 = restaurants[['poi_name', 'poi_rating', 'poi_review_count', 'poi_address', 'postal_code']].head(10)

# %%
# print(top_10.to_markdown(index=False))

# %% [markdown]
# #### Top 10 Restaurants based on their rating.
# | poi_name                    |   poi_rating |   poi_review_count | poi_address                | postal_code   |
# |:----------------------------|-------------:|-------------------:|:---------------------------|:--------------|
# | Tomah                       |            5 |                 12 | 132 Queen Street S         | L8P 3S2       |
# | Mystic Ramen                |            5 |                  6 | 51 King William Street     | L8R 1A2       |
# | Domino's Pizza              |            5 |                  5 | 86 Main Street Dundas ON   | L9H 2R1       |
# | Banh Mi Hue                 |            5 |                  4 | 127 MacNab Street N        | L8R 2B5       |
# | Tony G’s Pizzeria           |            5 |                  4 | 30 John Street N           | L8R 1G9       |
# | Joey Turks Island Grill     |            5 |                  3 | 178 Locke Street S         | L8P 4B3       |
# | Rosales diner               |            5 |                  3 | 303 Dundurn Street S       | L8P 4L4       |
# | The Indian Connection Pizza |            5 |                  3 | 1022 Barton Street E       | L8L 3E4       |
# | The Red Door Cucina         |            5 |                  3 | 21 King Street W Dundas ON | L9H 1T5       |
# | Cozy Sushi                  |            5 |                  2 | 6 Bold Street              | L8P 1T2       |
#
# <br>
#
# > Note: I factored in the Review Count in the sorting. I thought it made more sense if more than 1 person rated the place.
