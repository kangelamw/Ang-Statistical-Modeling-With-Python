# %% [markdown]
# # Cleaning Processes

# %%
# Imports
import pandas as pd
import re

# %%
# Load the data
citybikes = pd.read_csv('./sql_ready/citybikes.csv')
fsq = pd.read_csv('./raw/foursquare.csv')
yelp = pd.read_csv('./raw/yelp.csv')

print(f"{citybikes.shape} -- Citybikes is here.")
print(f"{fsq.shape} -- FSQ is here.")
print(f"{yelp.shape} -- Yelp is here.")
# Out:
# (190, 7) -- Citybikes is here.
# (8698, 12) -- FSQ is here.
# (10022, 12) -- Yelp is here.

# %% [markdown]
# ### Cleaning Addresses

# %%
# FSQ
fa = fsq.copy()
fa['poi_address'][0]
# Out:
# '328 James St N (Barton Street West), Hamilton ON L8L 1H2'

# %%
# Remove "Hamilton, ON"
fa['poi_address'] = fa['poi_address'].str.replace('Hamilton ON', '')

# Separate postal code
fa['postal_code'] = fa['poi_address'].str.extract(r'(\w\d\w\s\d\w\d)')

# Remove postal code
fa['poi_address'] = fa['poi_address'].str.replace(r'(\w\d\w\s\d\w\d)', '', regex=True)

# Remove comma
fa['poi_address'] = fa['poi_address'].str.replace(',', '')

# Remove leading and trailing spaces
fa['poi_address'] = fa['poi_address'].str.strip()

# %%
fa['poi_address'][0]
# Out:
# '328 James St N (Barton Street West)'

# %%
fa.head(1)
# Out:
#                      fsq_id poi_name  poi_category_id  poi_rating  \
# 0  5ba0f82a15173e002c280c07  Synonym            13065         NaN
#
#    poi_review_count  poi_latitude  poi_longitude  \
# 0               NaN     43.264558     -79.865376
#
#                            poi_address postal_code  \
# 0  328 James St N (Barton Street West)     L8L 1H2
#
#                          station_id  distance_from_station     station_name
# 0  024a3edf037cb411d16acc08a7fcb954                    420  Bay at Strachan

# %%
# Save
fa.to_csv('./raw/semi_processed/fa_foursquare.csv', index=False)

# %%
# Yelp
ya = yelp.copy()
ya['poi_address'][0]
# Out:
# "['200 Harbour Front Drive', 'Hamilton, ON L8L 1C8', 'Canada']"

# %%
# Remove brackets and quotes
ya['poi_address'] = ya['poi_address'].str.replace('[', '')
ya['poi_address'] = ya['poi_address'].str.replace(']', '')
ya['poi_address'] = ya['poi_address'].str.replace("'", '')

# Remove "Hamilton, ON" and "Canada"
ya['poi_address'] = ya['poi_address'].str.replace('Hamilton, ON', '')
ya['poi_address'] = ya['poi_address'].str.replace(' Canada', '')

# Remove comma(s)
ya['poi_address'] = ya['poi_address'].str.replace(',', '')

# Separate postal code
ya['postal_code'] = ya['poi_address'].str.extract(r'(\w\d\w\s\d\w\d)')

# Remove postal code
ya['poi_address'] = ya['poi_address'].str.replace(r'(\w\d\w\s\d\w\d)', '', regex=True)

# Remove extra spaces
ya['poi_address'] = ya['poi_address'].str.strip()

# %%
ya['poi_address'][0]
# Out:
# '200 Harbour Front Drive'

# %%
ya.head(1)
# Out:
#                   yelp_id             poi_name poi_category_id  poi_rating  \
# 0  fNfZ0bOEvXOxMP1vDEDi8w  Pirate Life Theatre  amusementparks         0.0
#
#    poi_review_count  poi_latitude  poi_longitude              poi_address  \
# 0                 0     43.268525     -79.870901  200 Harbour Front Drive
#
#   postal_code                        station_id  distance_from_station  \
# 0     L8L 1C8  024a3edf037cb411d16acc08a7fcb954             242.169774
#
#       station_name
# 0  Bay at Strachan

# %%
# Save
ya.to_csv('./raw/semi_processed/ya_yelp.csv', index=False)

# %% [markdown]
# ### Cleaning to obtain POI data only.

# %% [markdown]
# #### Foursquare

# %%
f_clean = fsq.copy()

# Inspect
print(f_clean.shape)
print(f_clean.columns)
# Out:
# (8698, 12)
# Index(['fsq_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
# Drop station data...
f_clean.drop(columns=['station_id', 'distance_from_station', 'station_name'], inplace=True)

print(f_clean.columns)
# Out:
# Index(['fsq_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code'],
#       dtype='object')

# %%
# Sort by poi_name and poi_address
f_clean.sort_values(by=['poi_name', 'poi_address'], inplace=True)

# Call duplicates
f_clean[f_clean.duplicated(subset=['poi_name', 'poi_address'])]
# Out:
#                         fsq_id               poi_name  poi_category_id  \
# 1023  5dd2e5df0cd86e00081bd28b       1101 Convenience            13065
# 1125  5dd2e5df0cd86e00081bd28b       1101 Convenience            13065
# 4111  5dd2e5df0cd86e00081bd28b       1101 Convenience            13065
# 5252  5dd2e5df0cd86e00081bd28b       1101 Convenience            13065
# 6274  5dd2e5df0cd86e00081bd28b       1101 Convenience            13065
# ...                        ...                    ...              ...
# 963   5a61374d23a2e61ce49b0922  Zyla's Music and Menu            13065
# 2202  5a61374d23a2e61ce49b0922  Zyla's Music and Menu            13065
# 4402  5a61374d23a2e61ce49b0922  Zyla's Music and Menu            13065
# 7034  5a61374d23a2e61ce49b0922  Zyla's Music and Menu            13065
# 7123  5a61374d23a2e61ce49b0922  Zyla's Music and Menu            13065
#
#       poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 1023         NaN               NaN     43.248628     -79.821565
# 1125         NaN               NaN     43.248628     -79.821565
# 4111         NaN               NaN     43.248628     -79.821565
# 5252         NaN               NaN     43.248628     -79.821565
# 6274         NaN               NaN     43.248628     -79.821565
# ...          ...               ...           ...            ...
# 963          NaN               NaN     43.264002     -79.866070
# 2202         NaN               NaN     43.264002     -79.866070
# 4402         NaN               NaN     43.264002     -79.866070
# 7034         NaN               NaN     43.264002     -79.866070
# 7123         NaN               NaN     43.264002     -79.866070
#
#                                             poi_address  postal_code
# 1023  1101 Cannon St E (Kensington), Hamilton ON L8L...          NaN
# 1125  1101 Cannon St E (Kensington), Hamilton ON L8L...          NaN
# 4111  1101 Cannon St E (Kensington), Hamilton ON L8L...          NaN
# 5252  1101 Cannon St E (Kensington), Hamilton ON L8L...          NaN
# 6274  1101 Cannon St E (Kensington), Hamilton ON L8L...          NaN
# ...                                                 ...          ...
# 963                 299 James St N, Hamilton ON L8R 2L4          NaN
# 2202                299 James St N, Hamilton ON L8R 2L4          NaN
# 4402                299 James St N, Hamilton ON L8R 2L4          NaN
# 7034                299 James St N, Hamilton ON L8R 2L4          NaN
# 7123                299 James St N, Hamilton ON L8R 2L4          NaN
#
# [8032 rows x 9 columns]

# %%
# Address cleaning
f_clean['poi_address'][0]
# Out:
# '328 James St N (Barton Street West), Hamilton ON L8L 1H2'

# %%
# Remove "Hamilton, ON"
f_clean['poi_address'] = f_clean['poi_address'].str.replace('Hamilton ON', '')

# Separate postal code
f_clean['postal_code'] = f_clean['poi_address'].str.extract(r'(\w\d\w\s\d\w\d)')

# Remove postal code
f_clean['poi_address'] = f_clean['poi_address'].str.replace(r'(\w\d\w\s\d\w\d)', '', regex=True)

# Remove comma
f_clean['poi_address'] = f_clean['poi_address'].str.replace(',', '')

# Remove leading and trailing spaces
f_clean['poi_address'] = f_clean['poi_address'].str.strip()

# %%
f_clean['poi_address'][0]
# Out:
# '328 James St N (Barton Street West)'

# %%
fsq_new = f_clean.drop_duplicates(subset=['poi_name', 'poi_address'], keep='first')

# %%
print(fsq_new.shape)
print(fsq_new.nunique())
# Out:
# (666, 9)
# fsq_id              666
# poi_name            586
# poi_category_id       3
# poi_rating            0
# poi_review_count      0
# poi_latitude        598
# poi_longitude       605
# poi_address         586
# postal_code         346
# dtype: int64

# %%
# Save a copy...
fsq_new.to_csv('./pois_only/pois_foursquare.csv', index=False)

# %% [markdown]
# #### Yelp

# %%
y_clean = yelp.copy()

# Inspect
print(y_clean.shape)
print(y_clean.columns)
# Out:
# (10022, 12)
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'station_id', 'distance_from_station', 'station_name'],
#       dtype='object')

# %%
# Drop station data...
y_clean.drop(columns=['station_id', 'distance_from_station', 'station_name'], inplace=True)

print(y_clean.columns)
# Out:
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code'],
#       dtype='object')

# %%
# Sort by poi_name and poi_address
y_clean.sort_values(by=['poi_name', 'poi_address'], inplace=True)

# Call duplicates
y_clean[y_clean.duplicated(subset=['poi_name', 'poi_address'])]
# Out:
#                      yelp_id               poi_name poi_category_id  \
# 1043  CODMFMsPP06eTQutMnniUA  541 Eatery & Exchange     restaurants
# 1144  CODMFMsPP06eTQutMnniUA  541 Eatery & Exchange     restaurants
# 1261  CODMFMsPP06eTQutMnniUA  541 Eatery & Exchange     restaurants
# 1316  CODMFMsPP06eTQutMnniUA  541 Eatery & Exchange     restaurants
# 1427  CODMFMsPP06eTQutMnniUA  541 Eatery & Exchange     restaurants
# ...                      ...                    ...             ...
# 3223  gI8lk0ROJVTR4f8BUVZClQ            sams tavern     restaurants
# 3542  gI8lk0ROJVTR4f8BUVZClQ            sams tavern     restaurants
# 3805  gI8lk0ROJVTR4f8BUVZClQ            sams tavern     restaurants
# 5334  gI8lk0ROJVTR4f8BUVZClQ            sams tavern     restaurants
# 8672  gI8lk0ROJVTR4f8BUVZClQ            sams tavern     restaurants
#
#       poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 1043         4.5                45     43.258248     -79.842354
# 1144         4.5                45     43.258248     -79.842354
# 1261         4.5                45     43.258248     -79.842354
# 1316         4.5                45     43.258248     -79.842354
# 1427         4.5                45     43.258248     -79.842354
# ...          ...               ...           ...            ...
# 3223         0.0                 0     43.256802     -79.838188
# 3542         0.0                 0     43.256802     -79.838188
# 3805         0.0                 0     43.256802     -79.838188
# 5334         0.0                 0     43.256802     -79.838188
# 8672         0.0                 0     43.256802     -79.838188
#
#                                             poi_address postal_code
# 1043  ['541 Barton Street E', 'Hamilton, ON L8L 2Z2'...     L8L 2Z2
# 1144  ['541 Barton Street E', 'Hamilton, ON L8L 2Z2'...     L8L 2Z2
# 1261  ['541 Barton Street E', 'Hamilton, ON L8L 2Z2'...     L8L 2Z2
# 1316  ['541 Barton Street E', 'Hamilton, ON L8L 2Z2'...     L8L 2Z2
# 1427  ['541 Barton Street E', 'Hamilton, ON L8L 2Z2'...     L8L 2Z2
# ...                                                 ...         ...
# 3223  ['632 Barton Street E', 'Hamilton, ON L8L 2Z9'...     L8L 2Z9
# 3542  ['632 Barton Street E', 'Hamilton, ON L8L 2Z9'...     L8L 2Z9
# 3805  ['632 Barton Street E', 'Hamilton, ON L8L 2Z9'...     L8L 2Z9
# 5334  ['632 Barton Street E', 'Hamilton, ON L8L 2Z9'...     L8L 2Z9
# 8672  ['632 Barton Street E', 'Hamilton, ON L8L 2Z9'...     L8L 2Z9
#
# [9494 rows x 9 columns]

# %%
# Address cleaning
y_clean['poi_address'][0]
# Out:
# "['200 Harbour Front Drive', 'Hamilton, ON L8L 1C8', 'Canada']"

# %%
# Remove brackets and quotes
y_clean['poi_address'] = y_clean['poi_address'].str.replace('[', '')
y_clean['poi_address'] = y_clean['poi_address'].str.replace(']', '')
y_clean['poi_address'] = y_clean['poi_address'].str.replace("'", '')

# Remove "Hamilton, ON" and "Canada"
y_clean['poi_address'] = y_clean['poi_address'].str.replace('Hamilton, ON', '')
y_clean['poi_address'] = y_clean['poi_address'].str.replace(' Canada', '')

# Remove comma(s)
y_clean['poi_address'] = y_clean['poi_address'].str.replace(',', '')

# Separate postal code
y_clean['postal_code'] = y_clean['poi_address'].str.extract(r'(\w\d\w\s\d\w\d)')

# Remove postal code
y_clean['poi_address'] = y_clean['poi_address'].str.replace(r'(\w\d\w\s\d\w\d)', '', regex=True)

# Remove extra spaces
y_clean['poi_address'] = y_clean['poi_address'].str.strip()

# %%
y_clean['poi_address'][0]
# Out:
# '200 Harbour Front Drive'

# %%
yp_new = y_clean.drop_duplicates(subset=['poi_name', 'poi_address'], keep='first')

# %%
print(yp_new.shape)
print(yp_new.nunique())
# Out:
# (528, 9)
# yelp_id             528
# poi_name            485
# poi_category_id       3
# poi_rating           41
# poi_review_count     74
# poi_latitude        493
# poi_longitude       500
# poi_address         485
# postal_code         323
# dtype: int64

# %%
# Save a copy...
yp_new.to_csv('./pois_only/pois_yelp.csv', index=False)

# %% [markdown]
# ### Combining POI data from Foursquare and Yelp

# %%
# Import CSVs from the previous step
fsq_c = pd.read_csv('./pois_only/pois_foursquare.csv')
yelp_c = pd.read_csv('./pois_only/pois_yelp.csv')

print(f"{fsq_c.shape} -- FSQ is here.") # Matched the previous step
print(f"{yelp_c.shape} -- Yelp is here.") # Matched the previous step
# Out:
# (666, 9) -- FSQ is here.
# (528, 9) -- Yelp is here.

# %%
# Columns
print(fsq_c.columns)
print(yelp_c.columns)
# Out:
# Index(['fsq_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code'],
#       dtype='object')
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code'],
#       dtype='object')

# %%
# I want to rename the poi_category_id columns to match the source, so I can fill in the missing values later
fsq_c.rename(columns={'poi_category_id' : 'f_category_id'}, inplace=True)
yelp_c.rename(columns={'poi_category_id' : 'y_category_id'}, inplace=True)

# %%
# Merge the two dataframes
pois_only = pd.concat([fsq_c, yelp_c], axis=0)

print(pois_only.shape)
print(pois_only.nunique())
# Out:
# (1194, 11)
# fsq_id               666
# poi_name             932
# f_category_id          3
# poi_rating            41
# poi_review_count      74
# poi_latitude        1083
# poi_longitude       1103
# poi_address         1047
# postal_code          465
# yelp_id              528
# y_category_id          3
# dtype: int64

# %%
pois_only.columns
# Out:
# Index(['fsq_id', 'poi_name', 'f_category_id', 'poi_rating', 'poi_review_count',
#        'poi_latitude', 'poi_longitude', 'poi_address', 'postal_code',
#        'yelp_id', 'y_category_id'],
#       dtype='object')

# %%
print(pois_only.shape)
print(pois_only.nunique())
# Out:
# (1194, 11)
# fsq_id               666
# poi_name             932
# f_category_id          3
# poi_rating            41
# poi_review_count      74
# poi_latitude        1083
# poi_longitude       1103
# poi_address         1047
# postal_code          465
# yelp_id              528
# y_category_id          3
# dtype: int64

# %%
# Call duplicates, sort by poi_name
pois_only[pois_only.duplicated(subset=['poi_name'])].sort_values(by='poi_name')
# Out:
#                        fsq_id                        poi_name  f_category_id  \
# 3                         NaN           541 Eatery & Exchange            NaN
# 8                         NaN                             A&W            NaN
# 7                         NaN                             A&W            NaN
# 9    503544ede4b0cde75df3b149                  A&W Restaurant        13065.0
# 10   4fe53cd6e4b0117428807583                  A&W Restaurant        13065.0
# ..                        ...                             ...            ...
# 514                       NaN             Williams Fresh Cafe            NaN
# 515                       NaN             Williams Fresh Cafe            NaN
# 650  4cc096adaa5776b0366e7544             Williams Fresh Cafe        13065.0
# 513                       NaN             Williams Fresh Cafe            NaN
# 519                       NaN  Workers Arts & Heritage Centre            NaN
#
#      poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 3           4.5              45.0     43.258248     -79.842354
# 8           2.0               1.0     43.250817     -79.807805
# 7           2.8               4.0     43.262025     -79.857941
# 9           NaN               NaN     43.262054     -79.857951
# 10          NaN               NaN     43.258550     -79.875118
# ..          ...               ...           ...            ...
# 514         2.7              22.0     43.257587     -79.917962
# 515         2.7              43.0     43.276487     -79.860838
# 650         NaN               NaN     43.276538     -79.860908
# 513         5.0               1.0     43.262245     -79.920286
# 519         0.0               0.0     43.266270     -79.867390
#
#                           poi_address postal_code                 yelp_id  \
# 3                 541 Barton Street E     L8L 2Z2  CODMFMsPP06eTQutMnniUA
# 8    Centre Mall 1275 Barton Street E     L8H 2V4  I2AnCv6ny7_kC7MAT2clGQ
# 7                 190 Barton Street E     L8L 2W8  GVdfb5969k4hQcnVMGKD6w
# 9                     190 Barton St E     L8L 2W8                     NaN
# 10                      194 King St W     L8P 1A5                     NaN
# ..                                ...         ...                     ...
# 514       1309 Main Street W Unit A-2     L8S 1C5  ZnDcWEpGFTwMqmXhpCa6fQ
# 515                47 Discovery Drive     L8L 8K4  iIpLGj-seyOgfOEtJMZlhQ
# 650    47 Discovery Dr (Guise St. E.)     L8L 8B4                     NaN
# 513           1280 Main Street W FL 2     L8S 4K1  TGXKszhNNure3bHQCbbTJA
# 519                  51 Stuart Street     L8L 1B5  bAlt353LtZW0H4ZcKVMMGQ
#
#     y_category_id
# 3     restaurants
# 8     restaurants
# 7     restaurants
# 9             NaN
# 10            NaN
# ..            ...
# 514   restaurants
# 515   restaurants
# 650           NaN
# 513   restaurants
# 519       museums
#
# [262 rows x 11 columns]

# %% [markdown]
# Time to fill in missing data.
# - `restaurants` on Yelp -- "13065" on Foursquare
# - `museums` on Yelp -- "10027" on Foursquare
# - `amusementparks` on Yelp -- "10001" on Foursquare

# %%
pois_only.head()
# Out:
#                      fsq_id                     poi_name  f_category_id  \
# 0  5dd2e5df0cd86e00081bd28b             1101 Convenience        13065.0
# 1  4dbb3d3ef7b1ab37dd3fe8f9      2 For 1 Pizza and Wings        13065.0
# 2  4f5e95a3e4b0253ade1e7454                    241 Pizza        13065.0
# 3  017dcad7abe249b50f10d5ed  31 Service Battalion Museum        10027.0
# 4  59907f940868a228a8f2c2f2           337 Sketch Gallery        10027.0
#
#    poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 0         NaN               NaN     43.248628     -79.821565
# 1         NaN               NaN     43.245058     -79.807569
# 2         NaN               NaN     43.250811     -79.851416
# 3         NaN               NaN     43.275168     -79.856177
# 4         NaN               NaN     43.251192     -79.816572
#
#                      poi_address postal_code yelp_id y_category_id
# 0  1101 Cannon St E (Kensington)     L8L 2J5     NaN           NaN
# 1           158 Kenilworth Ave N     L8H 4R8     NaN           NaN
# 2                  447 Main St E     L8N 1K1     NaN           NaN
# 3             650 Catharine St N         NaN     NaN           NaN
# 4  327 Ottawa St N (Barton St E)     L8H 3Z8     NaN           NaN

# %%
# Fill missing f_category_id values
pois_only.loc[pois_only['f_category_id'] == 13065.0, 'y_category_id'] = 'restaurants' # Restaurants
pois_only.loc[pois_only['f_category_id'] == 10027.0, 'y_category_id'] = 'museums' # Museums
pois_only.loc[pois_only['f_category_id'] == 10001.0, 'y_category_id'] = 'amusementparks' # Amusement Parks

# %%
# Fill missing y_category_id values
pois_only.loc[pois_only['y_category_id'] == 'restaurants', 'f_category_id'] = 10027.0 # Restaurants
pois_only.loc[pois_only['y_category_id'] == 'museums', 'f_category_id'] = 10027.0 # Museums
pois_only.loc[pois_only['y_category_id'] == 'amusementparks', 'f_category_id'] = 10001.0 # Amusement Parks

# %%
pois_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1194 entries, 0 to 527
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fsq_id            666 non-null    object
#  1   poi_name          1194 non-null   object
#  2   f_category_id     1194 non-null   float64
#  3   poi_rating        528 non-null    float64
#  4   poi_review_count  528 non-null    float64
#  5   poi_latitude      1194 non-null   float64
#  6   poi_longitude     1194 non-null   float64
#  7   poi_address       1192 non-null   object
#  8   postal_code       1163 non-null   object
#  9   yelp_id           528 non-null    object
#  10  y_category_id     1194 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 111.9+ KB

# %%
# Make our own ID
import random
import string

def generate_id():
    # Generate 2 random uppercase letters
    letters = ''.join(random.choices(string.ascii_uppercase, k=2))
    # Generate 4 random digits
    numbers = ''.join(random.choices(string.digits, k=4))
    # Combine letters and numbers
    return letters + numbers

pois_only['poi_id'] = pois_only['poi_name'].apply(lambda x: generate_id())

# %%
pois_only.columns
# Out:
# Index(['fsq_id', 'poi_name', 'f_category_id', 'poi_rating', 'poi_review_count',
#        'poi_latitude', 'poi_longitude', 'poi_address', 'postal_code',
#        'yelp_id', 'y_category_id', 'poi_id'],
#       dtype='object')

# %%
# Standardize the columns
pois_only['poi_category'] = pois_only['y_category_id']

pois_only.columns
# Out:
# Index(['fsq_id', 'poi_name', 'f_category_id', 'poi_rating', 'poi_review_count',
#        'poi_latitude', 'poi_longitude', 'poi_address', 'postal_code',
#        'yelp_id', 'y_category_id', 'poi_id', 'poi_category'],
#       dtype='object')

# %%
# Drop the old columns
pois_only.drop(columns=['f_category_id', 'y_category_id'], inplace=True)

# %%
pois_only.columns
# Out:
# Index(['fsq_id', 'poi_name', 'poi_rating', 'poi_review_count', 'poi_latitude',
#        'poi_longitude', 'poi_address', 'postal_code', 'yelp_id', 'poi_id',
#        'poi_category'],
#       dtype='object')

# %%
pois_only.head()
# Out:
#                      fsq_id                     poi_name  poi_rating  \
# 0  5dd2e5df0cd86e00081bd28b             1101 Convenience         NaN
# 1  4dbb3d3ef7b1ab37dd3fe8f9      2 For 1 Pizza and Wings         NaN
# 2  4f5e95a3e4b0253ade1e7454                    241 Pizza         NaN
# 3  017dcad7abe249b50f10d5ed  31 Service Battalion Museum         NaN
# 4  59907f940868a228a8f2c2f2           337 Sketch Gallery         NaN
#
#    poi_review_count  poi_latitude  poi_longitude  \
# 0               NaN     43.248628     -79.821565
# 1               NaN     43.245058     -79.807569
# 2               NaN     43.250811     -79.851416
# 3               NaN     43.275168     -79.856177
# 4               NaN     43.251192     -79.816572
#
#                      poi_address postal_code yelp_id  poi_id poi_category
# 0  1101 Cannon St E (Kensington)     L8L 2J5     NaN  RP1388  restaurants
# 1           158 Kenilworth Ave N     L8H 4R8     NaN  SY4399  restaurants
# 2                  447 Main St E     L8N 1K1     NaN  VX5752  restaurants
# 3             650 Catharine St N         NaN     NaN  BE5356      museums
# 4  327 Ottawa St N (Barton St E)     L8H 3Z8     NaN  AW7335      museums

# %%
pois_only.nunique()
# Out:
# fsq_id               666
# poi_name             932
# poi_rating            41
# poi_review_count      74
# poi_latitude        1083
# poi_longitude       1103
# poi_address         1047
# postal_code          465
# yelp_id              528
# poi_id              1194
# poi_category           3
# dtype: int64

# %%
# Back it up -- It's SQL ready.
pois_only.to_csv('./sql_ready/hamilton_pois.csv', index=False)

# %% [markdown]
# ### Cleaning Combined Data
#
# From `joining_data.ipynb`, I produced a dataset with all the POIs I was able to gather from both sources including the bike station info.

# %%
# Load the data
combined = pd.read_csv('../data/raw/combined_data.csv')

print(combined.shape)
print(combined.columns)
print(combined.nunique())
print(combined.info())
# Out:
# (19100, 19)
# Index(['fsq_id', 'poi_name', 'f_category_id', 'poi_rating', 'poi_review_count',
#        'poi_latitude', 'poi_longitude', 'poi_address', 'postal_code',
#        'station_id', 'distance_from_station', 'station_name',
#        'station_address', 'station_latitude', 'station_longitude',
#        'available_bikes', 'empty_bike_slots', 'yelp_id', 'y_category_id'],
#       dtype='object')
# fsq_id                     669
# poi_name                   932
# f_category_id                3
# poi_rating                  41
# poi_review_count            74
# poi_latitude              1086
# poi_longitude             1106
# poi_address               1047
# postal_code                465
# station_id                 190
# distance_from_station    10509
# station_name               190
# station_address            163
# station_latitude           190
# station_longitude          190
# available_bikes             19
# empty_bike_slots            25
# yelp_id                    529
# y_category_id                3
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19100 entries, 0 to 19099
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fsq_id                 8698 non-null   object
#  1   poi_name               18720 non-null  object
#  2   f_category_id          8698 non-null   float64
#  3   poi_rating             10022 non-null  float64
#  4   poi_review_count       10022 non-null  float64
#  5   poi_latitude           18720 non-null  float64
#  6   poi_longitude          18720 non-null  float64
#  7   poi_address            18698 non-null  object
#  8   postal_code            18335 non-null  object
#  9   station_id             19100 non-null  object
#  10  distance_from_station  18720 non-null  float64
#  11  station_name           19100 non-null  object
#  12  station_address        380 non-null    object
#  13  station_latitude       380 non-null    float64
#  14  station_longitude      380 non-null    float64
#  15  available_bikes        380 non-null    float64
#  16  empty_bike_slots       380 non-null    float64
#  17  yelp_id                10022 non-null  object
#  18  y_category_id          10022 non-null  object
# dtypes: float64(10), object(9)
# memory usage: 2.8+ MB
# None

# %%
combined.head()
# Out:
#                      fsq_id                           poi_name  f_category_id  \
# 0  5ba0f82a15173e002c280c07                            Synonym        13065.0
# 1  4fe7448be4b0faa0b99ed2c7             The Green Smoothie Bar        13065.0
# 2  54cbb92b498ec28817437edb  Saint James Espresso Bar & Eatery        13065.0
# 3  4b689c20f964a520be822be3                  The Harbour Diner        13065.0
# 4  520e97ce498e3ee7817abaf4                            Charred        13065.0
#
#    poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 0         NaN               NaN     43.264558     -79.865376
# 1         NaN               NaN     43.262531     -79.866285
# 2         NaN               NaN     43.260862     -79.866884
# 3         NaN               NaN     43.269474     -79.863286
# 4         NaN               NaN     43.262759     -79.866231
#
#                                       poi_address postal_code  \
# 0             328 James St N (Barton Street West)     L8L 1H2
# 1                                  236 James St N     L8R 2L3
# 2                         170 James St N (Cannon)     L8R 2L1
# 3   486 James St N (btwn Ferrie St and Picton St)     L8L 1J1
# 4  244 James St N (btwn Robert St & Colbourne St)     L8R 2L3
#
#                          station_id  distance_from_station     station_name  \
# 0  024a3edf037cb411d16acc08a7fcb954                  420.0  Bay at Strachan
# 1  024a3edf037cb411d16acc08a7fcb954                  606.0  Bay at Strachan
# 2  024a3edf037cb411d16acc08a7fcb954                  781.0  Bay at Strachan
# 3  024a3edf037cb411d16acc08a7fcb954                  415.0  Bay at Strachan
# 4  024a3edf037cb411d16acc08a7fcb954                  583.0  Bay at Strachan
#
#   station_address  station_latitude  station_longitude  available_bikes  \
# 0             NaN               NaN                NaN              NaN
# 1             NaN               NaN                NaN              NaN
# 2             NaN               NaN                NaN              NaN
# 3             NaN               NaN                NaN              NaN
# 4             NaN               NaN                NaN              NaN
#
#    empty_bike_slots yelp_id y_category_id
# 0               NaN     NaN           NaN
# 1               NaN     NaN           NaN
# 2               NaN     NaN           NaN
# 3               NaN     NaN           NaN
# 4               NaN     NaN           NaN

# %%
combined['station_address'] = citybikes['station_address']
combined['station_latitude'] = citybikes['station_latitude']
combined['station_longitude'] = citybikes['station_longitude']
combined['available_bikes'] = citybikes['available_bikes']
combined['empty_bike_slots'] = citybikes['empty_bike_slots']

combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19100 entries, 0 to 19099
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fsq_id                 8698 non-null   object
#  1   poi_name               18720 non-null  object
#  2   f_category_id          8698 non-null   float64
#  3   poi_rating             10022 non-null  float64
#  4   poi_review_count       10022 non-null  float64
#  5   poi_latitude           18720 non-null  float64
#  6   poi_longitude          18720 non-null  float64
#  7   poi_address            18698 non-null  object
#  8   postal_code            18335 non-null  object
#  9   station_id             19100 non-null  object
#  10  distance_from_station  18720 non-null  float64
#  11  station_name           19100 non-null  object
#  12  station_address        190 non-null    object
#  13  station_latitude       190 non-null    float64
#  14  station_longitude      190 non-null    float64
#  15  available_bikes        190 non-null    float64
#  16  empty_bike_slots       190 non-null    float64
#  17  yelp_id                10022 non-null  object
#  18  y_category_id          10022 non-null  object
# dtypes: float64(10), object(9)
# memory usage: 2.8+ MB

# %%
combined.head()
# Out:
#                      fsq_id                           poi_name  f_category_id  \
# 0  5ba0f82a15173e002c280c07                            Synonym        13065.0
# 1  4fe7448be4b0faa0b99ed2c7             The Green Smoothie Bar        13065.0
# 2  54cbb92b498ec28817437edb  Saint James Espresso Bar & Eatery        13065.0
# 3  4b689c20f964a520be822be3                  The Harbour Diner        13065.0
# 4  520e97ce498e3ee7817abaf4                            Charred        13065.0
#
#    poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 0         NaN               NaN     43.264558     -79.865376
# 1         NaN               NaN     43.262531     -79.866285
# 2         NaN               NaN     43.260862     -79.866884
# 3         NaN               NaN     43.269474     -79.863286
# 4         NaN               NaN     43.262759     -79.866231
#
#                                       poi_address postal_code  \
# 0             328 James St N (Barton Street West)     L8L 1H2
# 1                                  236 James St N     L8R 2L3
# 2                         170 James St N (Cannon)     L8R 2L1
# 3   486 James St N (btwn Ferrie St and Picton St)     L8L 1J1
# 4  244 James St N (btwn Robert St & Colbourne St)     L8R 2L3
#
#                          station_id  distance_from_station     station_name  \
# 0  024a3edf037cb411d16acc08a7fcb954                  420.0  Bay at Strachan
# 1  024a3edf037cb411d16acc08a7fcb954                  606.0  Bay at Strachan
# 2  024a3edf037cb411d16acc08a7fcb954                  781.0  Bay at Strachan
# 3  024a3edf037cb411d16acc08a7fcb954                  415.0  Bay at Strachan
# 4  024a3edf037cb411d16acc08a7fcb954                  583.0  Bay at Strachan
#
#                                      station_address  station_latitude  \
# 0                     325 Bay Street North, Hamilton         43.267859
# 1  2000 College Court, McMaster University, Hamilton         43.259178
# 2                     62-64 Augusta Street, Hamilton         43.251632
# 3                    36 Hunter Street East, Hamilton         43.253330
# 4                         394 Maple Avenue, Hamilton         43.242163
#
#    station_longitude  available_bikes  empty_bike_slots yelp_id y_category_id
# 0         -79.867923              1.0              23.0     NaN           NaN
# 1         -79.920503              2.0              12.0     NaN           NaN
# 2         -79.868980              0.0              10.0     NaN           NaN
# 3         -79.869533              6.0              11.0     NaN           NaN
# 4         -79.825003              4.0               5.0     NaN           NaN

# %%
# Fill missing f_category_id values
combined.loc[combined['f_category_id'] == 13065.0, 'y_category_id'] = 'restaurants' # Restaurants
combined.loc[combined['f_category_id'] == 10027.0, 'y_category_id'] = 'museums' # Museums
combined.loc[combined['f_category_id'] == 10001.0, 'y_category_id'] = 'amusementparks' # Amusement Parks

# %%
# Fill missing y_category_id values
combined.loc[combined['y_category_id'] == 'restaurants', 'f_category_id'] = 10027.0 # Restaurants
combined.loc[combined['y_category_id'] == 'museums', 'f_category_id'] = 10027.0 # Museums
combined.loc[combined['y_category_id'] == 'amusementparks', 'f_category_id'] = 10001.0 # Amusement Parks

# %%
combined.head()
# Out:
#                      fsq_id                           poi_name  f_category_id  \
# 0  5ba0f82a15173e002c280c07                            Synonym        10027.0
# 1  4fe7448be4b0faa0b99ed2c7             The Green Smoothie Bar        10027.0
# 2  54cbb92b498ec28817437edb  Saint James Espresso Bar & Eatery        10027.0
# 3  4b689c20f964a520be822be3                  The Harbour Diner        10027.0
# 4  520e97ce498e3ee7817abaf4                            Charred        10027.0
#
#    poi_rating  poi_review_count  poi_latitude  poi_longitude  \
# 0         NaN               NaN     43.264558     -79.865376
# 1         NaN               NaN     43.262531     -79.866285
# 2         NaN               NaN     43.260862     -79.866884
# 3         NaN               NaN     43.269474     -79.863286
# 4         NaN               NaN     43.262759     -79.866231
#
#                                       poi_address postal_code  \
# 0             328 James St N (Barton Street West)     L8L 1H2
# 1                                  236 James St N     L8R 2L3
# 2                         170 James St N (Cannon)     L8R 2L1
# 3   486 James St N (btwn Ferrie St and Picton St)     L8L 1J1
# 4  244 James St N (btwn Robert St & Colbourne St)     L8R 2L3
#
#                          station_id  distance_from_station     station_name  \
# 0  024a3edf037cb411d16acc08a7fcb954                  420.0  Bay at Strachan
# 1  024a3edf037cb411d16acc08a7fcb954                  606.0  Bay at Strachan
# 2  024a3edf037cb411d16acc08a7fcb954                  781.0  Bay at Strachan
# 3  024a3edf037cb411d16acc08a7fcb954                  415.0  Bay at Strachan
# 4  024a3edf037cb411d16acc08a7fcb954                  583.0  Bay at Strachan
#
#                                      station_address  station_latitude  \
# 0                     325 Bay Street North, Hamilton         43.267859
# 1  2000 College Court, McMaster University, Hamilton         43.259178
# 2                     62-64 Augusta Street, Hamilton         43.251632
# 3                    36 Hunter Street East, Hamilton         43.253330
# 4                         394 Maple Avenue, Hamilton         43.242163
#
#    station_longitude  available_bikes  empty_bike_slots yelp_id y_category_id
# 0         -79.867923              1.0              23.0     NaN   restaurants
# 1         -79.920503              2.0              12.0     NaN   restaurants
# 2         -79.868980              0.0              10.0     NaN   restaurants
# 3         -79.869533              6.0              11.0     NaN   restaurants
# 4         -79.825003              4.0               5.0     NaN   restaurants

# %%
# Standardize the columns
combined['poi_category'] = combined['y_category_id']
combined.drop(columns=['f_category_id', 'y_category_id'], inplace=True)

combined.head(2)
# Out:
#                      fsq_id                poi_name  poi_rating  \
# 0  5ba0f82a15173e002c280c07                 Synonym         NaN
# 1  4fe7448be4b0faa0b99ed2c7  The Green Smoothie Bar         NaN
#
#    poi_review_count  poi_latitude  poi_longitude  \
# 0               NaN     43.264558     -79.865376
# 1               NaN     43.262531     -79.866285
#
#                            poi_address postal_code  \
# 0  328 James St N (Barton Street West)     L8L 1H2
# 1                       236 James St N     L8R 2L3
#
#                          station_id  distance_from_station     station_name  \
# 0  024a3edf037cb411d16acc08a7fcb954                  420.0  Bay at Strachan
# 1  024a3edf037cb411d16acc08a7fcb954                  606.0  Bay at Strachan
#
#                                      station_address  station_latitude  \
# 0                     325 Bay Street North, Hamilton         43.267859
# 1  2000 College Court, McMaster University, Hamilton         43.259178
#
#    station_longitude  available_bikes  empty_bike_slots yelp_id poi_category
# 0         -79.867923              1.0              23.0     NaN  restaurants
# 1         -79.920503              2.0              12.0     NaN  restaurants

# %%
combined.shape
# Out:
# (19100, 18)

# %%
# Add poi_id
combined = pd.merge(pois_only, combined, how='left')

# %%
combined.head(2)
# Out:
#                      fsq_id          poi_name  poi_rating  poi_review_count  \
# 0  5dd2e5df0cd86e00081bd28b  1101 Convenience         NaN               NaN
# 1  5dd2e5df0cd86e00081bd28b  1101 Convenience         NaN               NaN
#
#    poi_latitude  poi_longitude                    poi_address postal_code  \
# 0     43.248628     -79.821565  1101 Cannon St E (Kensington)     L8L 2J5
# 1     43.248628     -79.821565  1101 Cannon St E (Kensington)     L8L 2J5
#
#   yelp_id  poi_id poi_category                        station_id  \
# 0     NaN  RP1388  restaurants  05fffdca01b4d886a823b025b6a04080
# 1     NaN  RP1388  restaurants  1846562b60f9d9469c055fed1d84898e
#
#    distance_from_station              station_name station_address  \
# 0                  770.0  Maple at Rothsay - ERI08             NaN
# 1                  548.0               King George             NaN
#
#    station_latitude  station_longitude  available_bikes  empty_bike_slots
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN

# %%
combined.shape
# Out:
# (18675, 19)

# %%
# Complete as it can be...
combined.to_csv('./sql_ready/hamilton_city_combined.csv', index=False)

# %% [markdown]
# ### Adding POI IDs to Foursquare and Yelp Data.
#
# More cleaning and standardizing columns for SQL

# %%
# Load the data
pois_foursquare = pd.read_csv('./pois_only/pois_foursquare.csv')
pois_yelp = pd.read_csv('./pois_only/pois_yelp.csv')

print(pois_foursquare.shape)
print(pois_yelp.shape)
# Out:
# (666, 9)
# (528, 9)

# %%
# Merge
f = pd.merge(pois_foursquare, pois_only, how='left')
y = pd.merge(pois_yelp, pois_only, how='left')

print(f"{f.shape} -- Foursquare")
print(f.columns)

print(f"{y.shape} -- Yelp")
print(y.columns)
# Out:
# (666, 12) -- Foursquare
# Index(['fsq_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'yelp_id', 'poi_id', 'poi_category'],
#       dtype='object')
# (528, 12) -- Yelp
# Index(['yelp_id', 'poi_name', 'poi_category_id', 'poi_rating',
#        'poi_review_count', 'poi_latitude', 'poi_longitude', 'poi_address',
#        'postal_code', 'fsq_id', 'poi_id', 'poi_category'],
#       dtype='object')

# %%
# Save to CSV
f.to_csv('./sql_ready/foursquare_data.csv', index=False)
y.to_csv('./sql_ready/yelp_data.csv', index=False)
